# %%
print("Ajoy Kumar")

# %%
install.packages("vcd", repos='http://R-Forge.R-project.org', lib= "/kaggle/working" )

# %%
library(vcd)

# %%
scales = c(7,11,15,20,19,11,18,10,6,22) 
temp= c(69,81,77,84,80,97,87,70,65,90)

# %%
mean(temp)

# %%
scales[-3];

# %%
scales[3] = 16

# %%
scales

# %%
names  = c("Tom", "Dick", "Harry")
names

# %%
ndvector =array(c(1,2,3,4,5,6,7,8,9,0), dim=c(5,2))
ndvector

# %%
icscales = data.frame(scales, temp)
icscales

# %%
dim(icscales)

# %%
summary(icscales)

# %%
data <- read.csv('/kaggle/input/datacsv/Student.csv')
data

# %%
colnames(data)
